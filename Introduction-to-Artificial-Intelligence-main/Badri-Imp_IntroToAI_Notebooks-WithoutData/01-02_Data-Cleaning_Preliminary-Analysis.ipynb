# %% [markdown]
# # Preliminary EDA

# %% [markdown]
# ## Importing Dataset

# %%
import numpy as np
import pandas as pd
import os
import math

# %%
path = os.getcwd()
files = os.listdir(path)
print(files[-1])
# Out:
# mergedCRDataset.csv

# %%
newPath = path+'\\'+files[-1]
print(newPath)
# Out:
# C:\Users\adhp460\OneDrive - City St George's, University of London\Intro to AI\Project_IntroToAI\mergedCRDataset.csv

# %%
crDf = pd.read_csv(newPath,sep='\t')

# %%
crDf.head(5)
# Out:
#                                             Crime ID    Month  \
# 0                                                NaN  2022-10
# 1  bbfa0d05cac4eb96ebfcb3151d30c243111e16c6ba312d...  2022-10
# 2  1cf1e07e2661faf3cb92d95640d0307e162d39f34a8528...  2022-10
# 3  fc0e7250330288ddd51e71087165804713acf4867b487b...  2022-10
# 4  e1dcd0b6da831c09fa9bf6c9963e469daa54b0a2de67c2...  2022-10
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.492876
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.491146
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.515659
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.491616
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.492876
#
#     Latitude                    Location  LSOA code  \
# 0  51.422716    On or near Trajectus Way  E01014399
# 1  51.425008  On or near Maximus Gardens  E01014399
# 2  51.408897   On or near Caroline Close  E01014399
# 3  51.424619     On or near Julius Place  E01014399
# 4  51.422716    On or near Trajectus Way  E01014399
#
#                            LSOA name                    Crime type  \
# 0  Bath and North East Somerset 001A         Anti-social behaviour
# 1  Bath and North East Somerset 001A                   Other theft
# 2  Bath and North East Somerset 001A  Violence and sexual offences
# 3  Bath and North East Somerset 001A  Violence and sexual offences
# 4  Bath and North East Somerset 001A  Violence and sexual offences
#
#          Last outcome category  Context
# 0                          NaN      NaN
# 1    Status update unavailable      NaN
# 2  Unable to prosecute suspect      NaN
# 3  Unable to prosecute suspect      NaN
# 4  Unable to prosecute suspect      NaN

# %% [markdown]
# ## Finding the number of Null values in the dataframe

# %%
crDf.isnull().sum()
# Out:
# Crime ID                  2984530
# Month                           0
# Reported by                     0
# Falls within                    0
# Longitude                  282309
# Latitude                   282309
# Location                        0
# LSOA code                  715465
# LSOA name                  715465
# Crime type                      0
# Last outcome category     3283554
# Context                  18102939
# dtype: int64

# %% [markdown]
# ## Finding unique values in all the columns

# %%
crDfUniqueSeries = pd.Series({c: crDf[c].unique() for c in crDf})
print(crDfUniqueSeries)
# Out:
# Crime ID                 [nan, bbfa0d05cac4eb96ebfcb3151d30c243111e16c6...
# Month                    [2022-10, 2022-11, 2022-12, 2023-01, 2023-02, ...
# Reported by              [Avon and Somerset Constabulary, Bedfordshire ...
# Falls within             [Avon and Somerset Constabulary, Bedfordshire ...
# Longitude                [-2.492876, -2.491146, -2.515659, -2.491616, -...
# Latitude                 [51.422716, 51.425008, 51.408897, 51.424619, 5...
# Location                 [On or near Trajectus Way, On or near Maximus ...
# LSOA code                [E01014399, E01014400, E01014401, E01014402, E...
# LSOA name                [Bath and North East Somerset 001A, Bath and N...
# Crime type               [Anti-social behaviour, Other theft, Violence ...
# Last outcome category    [nan, Status update unavailable, Unable to pro...
# Context                                                              [nan]
# dtype: object

# %%
print(crDfUniqueSeries['Crime type'])
# Out:
# ['Anti-social behaviour' 'Other theft' 'Violence and sexual offences'
#  'Other crime' 'Public order' 'Robbery' 'Vehicle crime'
#  'Criminal damage and arson' 'Bicycle theft' 'Burglary' 'Shoplifting'
#  'Drugs' 'Theft from the person' 'Possession of weapons']

# %% [markdown]
# ## Distribution of Other Column with respect to Target Column

# %%
# Source: https://www.statology.org/pandas-count-unique-values/

crDf.groupby('Crime type').nunique()
# Out:
#                               Crime ID  Month  Reported by  Falls within  \
# Crime type
# Anti-social behaviour                0     36           43            43
# Bicycle theft                   169701     36           44            44
# Burglary                        714642     36           44            44
# Criminal damage and arson      1330916     36           44            44
# Drugs                           523346     36           44            44
# Other crime                     356525     36           44            44
# Other theft                    1291464     36           44            44
# Possession of weapons           160921     36           44            44
# Public order                   1285368     36           44            44
# Robbery                         218727     36           44            44
# Shoplifting                    1329311     36           44            44
# Theft from the person           349645     36           44            44
# Vehicle crime                  1028789     36           44            44
# Violence and sexual offences   6052781     36           44            44
#
#                               Longitude  Latitude  Location  LSOA code  \
# Crime type
# Anti-social behaviour            437727    428655    195840      35000
# Bicycle theft                     78443     77585     46687      24098
# Burglary                         297082    291967    145941      34769
# Criminal damage and arson        392332    383817    181156      35019
# Drugs                            194090    190904    102147      33273
# Other crime                      191098    189144    103089      34078
# Other theft                      355259    347217    167869      35041
# Possession of weapons             98483     97981     57669      28886
# Public order                     330307    323954    158079      34978
# Robbery                           89843     88421     52139      25355
# Shoplifting                       59648     59279     30359      22927
# Theft from the person             71029     69670     42762      22664
# Vehicle crime                    338491    329914    162878      34836
# Violence and sexual offences     584548    568377    249905      35639
#
#                               LSOA name  Last outcome category  Context
# Crime type
# Anti-social behaviour             37067                      0        0
# Bicycle theft                     24677                     14        0
# Burglary                          36559                     14        0
# Criminal damage and arson         37040                     15        0
# Drugs                             34414                     15        0
# Other crime                       35273                     15        0
# Other theft                       37031                     15        0
# Possession of weapons             29543                     15        0
# Public order                      36904                     15        0
# Robbery                           25908                     15        0
# Shoplifting                       23737                     15        0
# Theft from the person             23173                     14        0
# Vehicle crime                     36724                     15        0
# Violence and sexual offences      37760                     15        0

# %% [markdown]
# ## Attemping to split LSOA code
#
# We wanted to see if spliting LSOA code may help in granularity of data, but observing the columns, it is mostly categorical.

# %%
crDf['LSOA code'].str.split('0',2,expand=True)
# Out:
# C:\Users\adhp460\AppData\Local\Temp\ipykernel_16332\2606692325.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   crDf['LSOA code'].str.split('0',2,expand=True)
#           0  1      2
# 0         E  1  14399
# 1         E  1  14399
# 2         E  1  14399
# 3         E  1  14399
# 4         E  1  14399
# ...      .. ..    ...
# 18102934  E  1  34558
# 18102935  E  1  34558
# 18102936  E  1  34558
# 18102937  E  1  25572
# 18102938  E  1  13362
#
# [18102939 rows x 3 columns]

# %% [markdown]
# ## Investigating why there are soo many null latitude and longitude nulls
#
# It mostly has the Last outcome category as Status Update unavailable or Under Investigation even though it contains many of the Crime Types, hence the location data is unavailable.

# %%
# Source: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

crLatNullDf = crDf.loc[crDf['Latitude'].isnull()]
crLatNullDf
# Out:
#                                                    Crime ID    Month  \
# 13265     8a4a96d3b3699a7db7e73a6bfbcb7c4bbe75bd472fd070...  2022-10
# 13266     c50fe36f770f1ebc06a2247696da816a4b284b6179ecbb...  2022-10
# 13267     6011b5ed988dcbc33ac772f0cad0d452caf4295653ca1a...  2022-10
# 13268     0bf214fa2fc4dc725b00a647adc6ee4414411310353adc...  2022-10
# 13269     512bfaa2b48e52e8dbaac96fcecd23da182b7b95589aaa...  2022-10
# ...                                                     ...      ...
# 18098820  f2ba12d84c4afc7df6dc620b842b5ae17446bcc5520573...  2025-09
# 18098821  8039c9bc7bd72853cf3070c885c6925cf3a68c9a369e93...  2025-09
# 18098822  74d751456d9ce1c4e99181bb26902fec1c868dd1fed76e...  2025-09
# 18098823  a6437739bbc8abb709ff18366ff29fd47f28320ba19b09...  2025-09
# 18098824  ab3edd4439ba0cbe8a9f2a3d2997713dbb57fb50a3bdff...  2025-09
#
#                              Reported by                    Falls within  \
# 13265     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 13266     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 13267     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 13268     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 13269     Avon and Somerset Constabulary  Avon and Somerset Constabulary
# ...                                  ...                             ...
# 18098820           West Yorkshire Police           West Yorkshire Police
# 18098821           West Yorkshire Police           West Yorkshire Police
# 18098822           West Yorkshire Police           West Yorkshire Police
# 18098823           West Yorkshire Police           West Yorkshire Police
# 18098824           West Yorkshire Police           West Yorkshire Police
#
#           Longitude  Latitude     Location LSOA code LSOA name     Crime type  \
# 13265           NaN       NaN  No Location       NaN       NaN  Bicycle theft
# 13266           NaN       NaN  No Location       NaN       NaN  Bicycle theft
# 13267           NaN       NaN  No Location       NaN       NaN  Bicycle theft
# 13268           NaN       NaN  No Location       NaN       NaN  Bicycle theft
# 13269           NaN       NaN  No Location       NaN       NaN  Bicycle theft
# ...             ...       ...          ...       ...       ...            ...
# 18098820        NaN       NaN  No Location       NaN       NaN    Other crime
# 18098821        NaN       NaN  No Location       NaN       NaN    Other crime
# 18098822        NaN       NaN  No Location       NaN       NaN    Other crime
# 18098823        NaN       NaN  No Location       NaN       NaN    Other crime
# 18098824        NaN       NaN  No Location       NaN       NaN    Other crime
#
#               Last outcome category  Context
# 13265     Status update unavailable      NaN
# 13266     Status update unavailable      NaN
# 13267     Status update unavailable      NaN
# 13268     Status update unavailable      NaN
# 13269     Status update unavailable      NaN
# ...                             ...      ...
# 18098820        Under investigation      NaN
# 18098821        Under investigation      NaN
# 18098822        Under investigation      NaN
# 18098823        Under investigation      NaN
# 18098824        Under investigation      NaN
#
# [282309 rows x 12 columns]

# %%
# Source: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.unique.html
# Source: https://stackoverflow.com/questions/47933213/list-unique-values-in-a-pandas-dataframe

nullLatSeries = pd.Series({c: crLatNullDf[c].unique() for c in crLatNullDf})
print(nullLatSeries)
# Out:
# Crime ID                 [8a4a96d3b3699a7db7e73a6bfbcb7c4bbe75bd472fd07...
# Month                    [2022-10, 2022-11, 2022-12, 2023-01, 2023-02, ...
# Reported by              [Avon and Somerset Constabulary, Bedfordshire ...
# Falls within             [Avon and Somerset Constabulary, Bedfordshire ...
# Longitude                                                            [nan]
# Latitude                                                             [nan]
# Location                                                     [No Location]
# LSOA code                                                            [nan]
# LSOA name                                                            [nan]
# Crime type               [Bicycle theft, Burglary, Criminal damage and ...
# Last outcome category    [Status update unavailable, Unable to prosecut...
# Context                                                              [nan]
# dtype: object

# %%
print(nullLatSeries['Crime type'])
# Out:
# ['Bicycle theft' 'Burglary' 'Criminal damage and arson' 'Drugs'
#  'Other theft' 'Possession of weapons' 'Public order' 'Robbery'
#  'Shoplifting' 'Theft from the person' 'Vehicle crime'
#  'Violence and sexual offences' 'Other crime' 'Anti-social behaviour']

# %%
crLatNullDf.groupby('Crime type').nunique()
# Out:
#                               Crime ID  Month  Reported by  Falls within  \
# Crime type
# Anti-social behaviour                0     36           28            28
# Bicycle theft                     3389     36           30            30
# Burglary                         11394     36           30            30
# Criminal damage and arson        21931     36           32            32
# Drugs                            13253     36           30            30
# Other crime                      10609     36           30            30
# Other theft                      27951     36           31            31
# Possession of weapons             3367     36           31            31
# Public order                     24993     36           31            31
# Robbery                           4488     36           30            30
# Shoplifting                      21010     36           30            30
# Theft from the person             7012     36           30            30
# Vehicle crime                    16169     36           30            30
# Violence and sexual offences    109823     36           33            33
#
#                               Longitude  Latitude  Location  LSOA code  \
# Crime type
# Anti-social behaviour                 0         0         1          0
# Bicycle theft                         0         0         1          0
# Burglary                              0         0         1          0
# Criminal damage and arson             0         0         1          0
# Drugs                                 0         0         1          0
# Other crime                           0         0         1          0
# Other theft                           0         0         1          0
# Possession of weapons                 0         0         1          0
# Public order                          0         0         1          0
# Robbery                               0         0         1          0
# Shoplifting                           0         0         1          0
# Theft from the person                 0         0         1          0
# Vehicle crime                         0         0         1          0
# Violence and sexual offences          0         0         1          0
#
#                               LSOA name  Last outcome category  Context
# Crime type
# Anti-social behaviour                 0                      0        0
# Bicycle theft                         0                     13        0
# Burglary                              0                     13        0
# Criminal damage and arson             0                     14        0
# Drugs                                 0                     15        0
# Other crime                           0                     13        0
# Other theft                           0                     14        0
# Possession of weapons                 0                     12        0
# Public order                          0                     14        0
# Robbery                               0                     14        0
# Shoplifting                           0                     15        0
# Theft from the person                 0                     12        0
# Vehicle crime                         0                     13        0
# Violence and sexual offences          0                     14        0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Removing Null values

# %%
#Source: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

crCleanDf = crDf.drop(columns=['Crime ID','Last outcome category','Context'])

# %%
crCleanDf = crCleanDf.dropna()

# %%
crCleanDf.head(5)
# Out:
#      Month                     Reported by                    Falls within  \
# 0  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 1  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 2  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 3  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 4  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
#
#    Longitude   Latitude                    Location  LSOA code  \
# 0  -2.492876  51.422716    On or near Trajectus Way  E01014399
# 1  -2.491146  51.425008  On or near Maximus Gardens  E01014399
# 2  -2.515659  51.408897   On or near Caroline Close  E01014399
# 3  -2.491616  51.424619     On or near Julius Place  E01014399
# 4  -2.492876  51.422716    On or near Trajectus Way  E01014399
#
#                            LSOA name                    Crime type
# 0  Bath and North East Somerset 001A         Anti-social behaviour
# 1  Bath and North East Somerset 001A                   Other theft
# 2  Bath and North East Somerset 001A  Violence and sexual offences
# 3  Bath and North East Somerset 001A  Violence and sexual offences
# 4  Bath and North East Somerset 001A  Violence and sexual offences

# %% [markdown]
# ## Splitting Month column into year and month number

# %%
# Src: https://stackoverflow.com/questions/14745022/how-to-split-a-dataframe-string-column-into-two-columns
# Src: https://stackoverflow.com/questions/46585193/pandas-error-in-python-columns-must-be-same-length-as-key

crCleanDf[['Year','Month Num']] = crCleanDf['Month'].str.split('-',expand=True)
print(crCleanDf)
# Out:
#             Month                     Reported by  \
# 0         2022-10  Avon and Somerset Constabulary
# 1         2022-10  Avon and Somerset Constabulary
# 2         2022-10  Avon and Somerset Constabulary
# 3         2022-10  Avon and Somerset Constabulary
# 4         2022-10  Avon and Somerset Constabulary
# ...           ...                             ...
# 18102934  2025-09                Wiltshire Police
# 18102935  2025-09                Wiltshire Police
# 18102936  2025-09                Wiltshire Police
# 18102937  2025-09                Wiltshire Police
# 18102938  2025-09                Wiltshire Police
#
#                             Falls within  Longitude   Latitude  \
# 0         Avon and Somerset Constabulary  -2.492876  51.422716
# 1         Avon and Somerset Constabulary  -2.491146  51.425008
# 2         Avon and Somerset Constabulary  -2.515659  51.408897
# 3         Avon and Somerset Constabulary  -2.491616  51.424619
# 4         Avon and Somerset Constabulary  -2.492876  51.422716
# ...                                  ...        ...        ...
# 18102934                Wiltshire Police  -1.662425  51.226816
# 18102935                Wiltshire Police  -1.661462  51.225294
# 18102936                Wiltshire Police  -1.662679  51.225342
# 18102937                Wiltshire Police  -3.041070  53.888606
# 18102938                Wiltshire Police  -1.073869  53.944344
#
#                                Location  LSOA code  \
# 0              On or near Trajectus Way  E01014399
# 1            On or near Maximus Gardens  E01014399
# 2             On or near Caroline Close  E01014399
# 3               On or near Julius Place  E01014399
# 4              On or near Trajectus Way  E01014399
# ...                                 ...        ...
# 18102934  On or near Rorkes Drift Drive  E01034558
# 18102935       On or near Alamein Close  E01034558
# 18102936        On or near Talavera Way  E01034558
# 18102937        On or near The Way Gate  E01025572
# 18102938        On or near Fulford Road  E01013362
#
#                                   LSOA name                    Crime type  \
# 0         Bath and North East Somerset 001A         Anti-social behaviour
# 1         Bath and North East Somerset 001A                   Other theft
# 2         Bath and North East Somerset 001A  Violence and sexual offences
# 3         Bath and North East Somerset 001A  Violence and sexual offences
# 4         Bath and North East Somerset 001A  Violence and sexual offences
# ...                                     ...                           ...
# 18102934                     Wiltshire 066E  Violence and sexual offences
# 18102935                     Wiltshire 066E  Violence and sexual offences
# 18102936                     Wiltshire 066E  Violence and sexual offences
# 18102937                          Wyre 008E  Violence and sexual offences
# 18102938                          York 019C  Violence and sexual offences
#
#           Year Month Num
# 0         2022        10
# 1         2022        10
# 2         2022        10
# 3         2022        10
# 4         2022        10
# ...        ...       ...
# 18102934  2025        09
# 18102935  2025        09
# 18102936  2025        09
# 18102937  2025        09
# 18102938  2025        09
#
# [17387474 rows x 11 columns]

# %%
crCleanDf.head(5)
# Out:
#      Month                     Reported by                    Falls within  \
# 0  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 1  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 2  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 3  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 4  2022-10  Avon and Somerset Constabulary  Avon and Somerset Constabulary
#
#    Longitude   Latitude                    Location  LSOA code  \
# 0  -2.492876  51.422716    On or near Trajectus Way  E01014399
# 1  -2.491146  51.425008  On or near Maximus Gardens  E01014399
# 2  -2.515659  51.408897   On or near Caroline Close  E01014399
# 3  -2.491616  51.424619     On or near Julius Place  E01014399
# 4  -2.492876  51.422716    On or near Trajectus Way  E01014399
#
#                            LSOA name                    Crime type  Year  \
# 0  Bath and North East Somerset 001A         Anti-social behaviour  2022
# 1  Bath and North East Somerset 001A                   Other theft  2022
# 2  Bath and North East Somerset 001A  Violence and sexual offences  2022
# 3  Bath and North East Somerset 001A  Violence and sexual offences  2022
# 4  Bath and North East Somerset 001A  Violence and sexual offences  2022
#
#   Month Num
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10

# %%
crCleanDf = crCleanDf.drop(columns=['Month'])

# %%
# Src = https://www.geeksforgeeks.org/python/how-to-move-a-column-to-first-position-in-pandas-dataframe/

tempCols = ['Year'] + ['Month Num'] + [col for col in crCleanDf.columns if col != 'Year' and col!='Month Num']
print(tempCols)
# Out:
# ['Year', 'Month Num', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type']

# %%
crCleanDf = crCleanDf.reindex(columns=tempCols)
crCleanDf.head(5)
# Out:
#    Year Month Num                     Reported by  \
# 0  2022        10  Avon and Somerset Constabulary
# 1  2022        10  Avon and Somerset Constabulary
# 2  2022        10  Avon and Somerset Constabulary
# 3  2022        10  Avon and Somerset Constabulary
# 4  2022        10  Avon and Somerset Constabulary
#
#                      Falls within  Longitude   Latitude  \
# 0  Avon and Somerset Constabulary  -2.492876  51.422716
# 1  Avon and Somerset Constabulary  -2.491146  51.425008
# 2  Avon and Somerset Constabulary  -2.515659  51.408897
# 3  Avon and Somerset Constabulary  -2.491616  51.424619
# 4  Avon and Somerset Constabulary  -2.492876  51.422716
#
#                      Location  LSOA code                          LSOA name  \
# 0    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
# 1  On or near Maximus Gardens  E01014399  Bath and North East Somerset 001A
# 2   On or near Caroline Close  E01014399  Bath and North East Somerset 001A
# 3     On or near Julius Place  E01014399  Bath and North East Somerset 001A
# 4    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
#
#                      Crime type
# 0         Anti-social behaviour
# 1                   Other theft
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4  Violence and sexual offences

# %%
crCleanDf.isnull().sum()
# Out:
# Year            0
# Month Num       0
# Reported by     0
# Falls within    0
# Longitude       0
# Latitude        0
# Location        0
# LSOA code       0
# LSOA name       0
# Crime type      0
# dtype: int64

# %% [markdown]
# # saving cleaned data
#
# Source: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html https://stackoverflow.com/questions/16923281/writing-a-pandas-dataframe-to-csv-file

# %%
crCleanDf.to_csv('mergedCleanedCRDataset.csv',sep='\t',encoding='utf-8',index=False,header=True)

# %% [markdown]
# # Loading cleaned data and Observing the distribution of the crime types

# %%
import numpy as np
import pandas as pd
import os
import math

path = os.getcwd()
files = os.listdir(path)
print(files[-2])

newPath = path+'\\'+files[-2]
print(newPath)

crCleanDf = pd.read_csv(newPath,sep='\t')
crCleanDf.head()
# Out:
# mergedCleanedCRDataset.csv
# C:\Users\adhp460\OneDrive - City St George's, University of London\Intro to AI\Project_IntroToAI\mergedCleanedCRDataset.csv
#    Year  Month Num                     Reported by  \
# 0  2022         10  Avon and Somerset Constabulary
# 1  2022         10  Avon and Somerset Constabulary
# 2  2022         10  Avon and Somerset Constabulary
# 3  2022         10  Avon and Somerset Constabulary
# 4  2022         10  Avon and Somerset Constabulary
#
#                      Falls within  Longitude   Latitude  \
# 0  Avon and Somerset Constabulary  -2.492876  51.422716
# 1  Avon and Somerset Constabulary  -2.491146  51.425008
# 2  Avon and Somerset Constabulary  -2.515659  51.408897
# 3  Avon and Somerset Constabulary  -2.491616  51.424619
# 4  Avon and Somerset Constabulary  -2.492876  51.422716
#
#                      Location  LSOA code                          LSOA name  \
# 0    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
# 1  On or near Maximus Gardens  E01014399  Bath and North East Somerset 001A
# 2   On or near Caroline Close  E01014399  Bath and North East Somerset 001A
# 3     On or near Julius Place  E01014399  Bath and North East Somerset 001A
# 4    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
#
#                      Crime type
# 0         Anti-social behaviour
# 1                   Other theft
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4  Violence and sexual offences

# %%
# src: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html

targetDist = crCleanDf['Crime type'].value_counts(normalize=True)
print(targetDist)
# Out:
# Violence and sexual offences    0.345162
# Anti-social behaviour           0.158195
# Criminal damage and arson       0.075512
# Shoplifting                     0.074977
# Public order                    0.073858
# Other theft                     0.073084
# Vehicle crime                   0.058217
# Burglary                        0.040255
# Drugs                           0.029248
# Theft from the person           0.020332
# Other crime                     0.019715
# Robbery                         0.012595
# Bicycle theft                   0.009842
# Possession of weapons           0.009006
# Name: Crime type, dtype: float64

# %%
# src: https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html
import matplotlib.pyplot as plt
plt.pie(targetDist,labels = targetDist.index, labeldistance=1.3)
plt.show()
