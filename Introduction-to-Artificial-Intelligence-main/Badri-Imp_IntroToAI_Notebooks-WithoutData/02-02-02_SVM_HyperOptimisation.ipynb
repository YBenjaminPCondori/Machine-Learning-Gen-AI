# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import math

import os

import matplotlib.pyplot as plt

import sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Getting File Path

# %%
path = os.getcwd()
files = os.listdir(path)
print(files[-3])

newPath = path+'\\mergedCleanedCRDataset.csv'
print(newPath)
# Out:
# Random_Forest-Implementation.ipynb
# C:\Users\nbadr\OneDrive - City St George's, University of London\Intro to AI\Project_IntroToAI\mergedCleanedCRDataset.csv

# %%
crDf = pd.read_csv(newPath,sep='\t')
crDf.head()
# Out:
#    Year  Month Num                     Reported by  \
# 0  2022         10  Avon and Somerset Constabulary
# 1  2022         10  Avon and Somerset Constabulary
# 2  2022         10  Avon and Somerset Constabulary
# 3  2022         10  Avon and Somerset Constabulary
# 4  2022         10  Avon and Somerset Constabulary
#
#                      Falls within  Longitude   Latitude  \
# 0  Avon and Somerset Constabulary  -2.492876  51.422716
# 1  Avon and Somerset Constabulary  -2.491146  51.425008
# 2  Avon and Somerset Constabulary  -2.515659  51.408897
# 3  Avon and Somerset Constabulary  -2.491616  51.424619
# 4  Avon and Somerset Constabulary  -2.492876  51.422716
#
#                      Location  LSOA code                          LSOA name  \
# 0    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
# 1  On or near Maximus Gardens  E01014399  Bath and North East Somerset 001A
# 2   On or near Caroline Close  E01014399  Bath and North East Somerset 001A
# 3     On or near Julius Place  E01014399  Bath and North East Somerset 001A
# 4    On or near Trajectus Way  E01014399  Bath and North East Somerset 001A
#
#                      Crime type
# 0         Anti-social behaviour
# 1                   Other theft
# 2  Violence and sexual offences
# 3  Violence and sexual offences
# 4  Violence and sexual offences

# %% [markdown]
# # Label Encoding
#
# Converting categorical columns into numerical ones

# %%
crEncDf = crDf.copy()

for i in crEncDf.columns:
    if not (i == 'Longitude' or i=='Latitude'):
        labEnc = LabelEncoder()
        crEncDf[i] = labEnc.fit_transform(crEncDf[i])

crEncDf.head()
# Out:
#    Year  Month Num  Reported by  Falls within  Longitude   Latitude  Location  \
# 0     0          9            0             0  -2.492876  51.422716    246246
# 1     0          9            0             0  -2.491146  51.425008    160787
# 2     0          9            0             0  -2.515659  51.408897     45587
# 3     0          9            0             0  -2.491616  51.424619    133151
# 4     0          9            0             0  -2.492876  51.422716    246246
#
#    LSOA code  LSOA name  Crime type
# 0      13087       1481           0
# 1      13087       1481           6
# 2      13087       1481          13
# 3      13087       1481          13
# 4      13087       1481          13

# %% [markdown]
# # Location Data Normalisation
#
# Here we are normalising the Longitude and Latitude between a 0 to 1 scale, we may lose some data, but it ensures that it is easier for the models to process those columns

# %%
crScalDf = crEncDf.copy()

for i in crScalDf.columns:
    if (i == 'Longitude' or i=='Latitude'):
        minMaxScal = MinMaxScaler()
        crScalDf[i] = minMaxScal.fit_transform(crScalDf[i].to_numpy().reshape(-1,1)).flatten()

crScalDf.head()
# Out:
#    Year  Month Num  Reported by  Falls within  Longitude  Latitude  Location  \
# 0     0          9            0             0   0.475959  0.259476    246246
# 1     0          9            0             0   0.476172  0.259865    160787
# 2     0          9            0             0   0.473152  0.257133     45587
# 3     0          9            0             0   0.476114  0.259799    133151
# 4     0          9            0             0   0.475959  0.259476    246246
#
#    LSOA code  LSOA name  Crime type
# 0      13087       1481           0
# 1      13087       1481           6
# 2      13087       1481          13
# 3      13087       1481          13
# 4      13087       1481          13

# %% [markdown]
# # Train Test Split
#
# Train Size is 70%
# Test Size is 30%
# Random State is 16
#
# Here we are limiting the number of rows, as SVC is a computationally inefficient model
#
# Testing using hyperparameter tuning of Parameters

# %%
x = crScalDf.drop(columns='Crime type')
y = crScalDf['Crime type']

xTrain, xTest, yTrain, yTest = train_test_split(x,y,test_size=0.3,random_state=16)

xTrain = xTrain[:10000]
xTest = xTest[:10000]
yTrain = yTrain[:10000]
yTest = yTest[:10000]

# %% [markdown]
# ## Creating a list of parameters to test
#
# Did not include linear in Kernal as it only Precomputed for square matrix

# %%
svmParamsC = [0.75,0.8,0.9,1.0,1.1,1.2,1.25]
svmParamsKer = ['poly','rbf','sigmoid']
svmParamsDeg = [1,2,3,4,5]
svmParamsGam = ['scale','auto']
svmParamsBreakTies = [ False, True ]
svmParamsDFS = ['ovo','ovr']
svmModelArr = []
svmModelParams = []
accList = []

# %%
#Src: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

for h in svmParamsDFS:
    for i in svmParamsC:
        for j in svmParamsBreakTies:
            for k in svmParamsKer:
                if k == 'poly':
                    for l in svmParamsDeg:
                        svmTemp = SVC(C=i,kernel=k,degree=l,break_ties=j,decision_function_shape=h,verbose=True)
                        svmModelArr.append(svmTemp)
                        svmModelParams.append([i,j,k,l,h])
                else:
                    for l in svmParamsGam:
                        svmTemp = SVC(C=i,kernel=k,gamma=l,break_ties=j,decision_function_shape=h,verbose=True)
                        svmModelArr.append(svmTemp)
                        svmModelParams.append([i,j,k,l,h])

# %%
for i in svmModelArr:
    print(i)
# Out:
# SVC(C=0.75, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=0.75, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# SVC(decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# SVC(decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# SVC(decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# SVC(decision_function_shape='ovo', verbose=True)
# SVC(decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(decision_function_shape='ovo', gamma='auto', kernel='sigmoid', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.75, degree=1, kernel='poly', verbose=True)
# SVC(C=0.75, degree=2, kernel='poly', verbose=True)
# SVC(C=0.75, kernel='poly', verbose=True)
# SVC(C=0.75, degree=4, kernel='poly', verbose=True)
# SVC(C=0.75, degree=5, kernel='poly', verbose=True)
# SVC(C=0.75, verbose=True)
# SVC(C=0.75, gamma='auto', verbose=True)
# SVC(C=0.75, kernel='sigmoid', verbose=True)
# SVC(C=0.75, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=0.75, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, verbose=True)
# SVC(C=0.75, break_ties=True, gamma='auto', verbose=True)
# SVC(C=0.75, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=0.75, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=0.8, degree=1, kernel='poly', verbose=True)
# SVC(C=0.8, degree=2, kernel='poly', verbose=True)
# SVC(C=0.8, kernel='poly', verbose=True)
# SVC(C=0.8, degree=4, kernel='poly', verbose=True)
# SVC(C=0.8, degree=5, kernel='poly', verbose=True)
# SVC(C=0.8, verbose=True)
# SVC(C=0.8, gamma='auto', verbose=True)
# SVC(C=0.8, kernel='sigmoid', verbose=True)
# SVC(C=0.8, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=0.8, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, verbose=True)
# SVC(C=0.8, break_ties=True, gamma='auto', verbose=True)
# SVC(C=0.8, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=0.8, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=0.9, degree=1, kernel='poly', verbose=True)
# SVC(C=0.9, degree=2, kernel='poly', verbose=True)
# SVC(C=0.9, kernel='poly', verbose=True)
# SVC(C=0.9, degree=4, kernel='poly', verbose=True)
# SVC(C=0.9, degree=5, kernel='poly', verbose=True)
# SVC(C=0.9, verbose=True)
# SVC(C=0.9, gamma='auto', verbose=True)
# SVC(C=0.9, kernel='sigmoid', verbose=True)
# SVC(C=0.9, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=0.9, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, verbose=True)
# SVC(C=0.9, break_ties=True, gamma='auto', verbose=True)
# SVC(C=0.9, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=0.9, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(degree=1, kernel='poly', verbose=True)
# SVC(degree=2, kernel='poly', verbose=True)
# SVC(kernel='poly', verbose=True)
# SVC(degree=4, kernel='poly', verbose=True)
# SVC(degree=5, kernel='poly', verbose=True)
# SVC(verbose=True)
# SVC(gamma='auto', verbose=True)
# SVC(kernel='sigmoid', verbose=True)
# SVC(gamma='auto', kernel='sigmoid', verbose=True)
# SVC(break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(break_ties=True, kernel='poly', verbose=True)
# SVC(break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(break_ties=True, verbose=True)
# SVC(break_ties=True, gamma='auto', verbose=True)
# SVC(break_ties=True, kernel='sigmoid', verbose=True)
# SVC(break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.1, degree=1, kernel='poly', verbose=True)
# SVC(C=1.1, degree=2, kernel='poly', verbose=True)
# SVC(C=1.1, kernel='poly', verbose=True)
# SVC(C=1.1, degree=4, kernel='poly', verbose=True)
# SVC(C=1.1, degree=5, kernel='poly', verbose=True)
# SVC(C=1.1, verbose=True)
# SVC(C=1.1, gamma='auto', verbose=True)
# SVC(C=1.1, kernel='sigmoid', verbose=True)
# SVC(C=1.1, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.1, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, verbose=True)
# SVC(C=1.1, break_ties=True, gamma='auto', verbose=True)
# SVC(C=1.1, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=1.1, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.2, degree=1, kernel='poly', verbose=True)
# SVC(C=1.2, degree=2, kernel='poly', verbose=True)
# SVC(C=1.2, kernel='poly', verbose=True)
# SVC(C=1.2, degree=4, kernel='poly', verbose=True)
# SVC(C=1.2, degree=5, kernel='poly', verbose=True)
# SVC(C=1.2, verbose=True)
# SVC(C=1.2, gamma='auto', verbose=True)
# SVC(C=1.2, kernel='sigmoid', verbose=True)
# SVC(C=1.2, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.2, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, verbose=True)
# SVC(C=1.2, break_ties=True, gamma='auto', verbose=True)
# SVC(C=1.2, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=1.2, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.25, degree=1, kernel='poly', verbose=True)
# SVC(C=1.25, degree=2, kernel='poly', verbose=True)
# SVC(C=1.25, kernel='poly', verbose=True)
# SVC(C=1.25, degree=4, kernel='poly', verbose=True)
# SVC(C=1.25, degree=5, kernel='poly', verbose=True)
# SVC(C=1.25, verbose=True)
# SVC(C=1.25, gamma='auto', verbose=True)
# SVC(C=1.25, kernel='sigmoid', verbose=True)
# SVC(C=1.25, gamma='auto', kernel='sigmoid', verbose=True)
# SVC(C=1.25, break_ties=True, degree=1, kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, degree=2, kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, degree=4, kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, degree=5, kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, verbose=True)
# SVC(C=1.25, break_ties=True, gamma='auto', verbose=True)
# SVC(C=1.25, break_ties=True, kernel='sigmoid', verbose=True)
# SVC(C=1.25, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)

# %%
for j in svmModelArr:
    print(j)
    j.fit(xTrain,yTrain)
# Out:
# SVC(C=0.75, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.75, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(decision_function_shape='ovo', gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.75, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, verbose=True)
# [LibSVM]SVC(C=0.75, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.75, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.75, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.75, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, verbose=True)
# [LibSVM]SVC(C=0.8, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.8, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.8, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, verbose=True)
# [LibSVM]SVC(C=0.9, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.9, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=0.9, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(kernel='poly', verbose=True)
# [LibSVM]SVC(degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(verbose=True)
# [LibSVM]SVC(gamma='auto', verbose=True)
# [LibSVM]SVC(kernel='sigmoid', verbose=True)
# [LibSVM]SVC(gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(break_ties=True, verbose=True)
# [LibSVM]SVC(break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, verbose=True)
# [LibSVM]SVC(C=1.1, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.1, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.1, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, verbose=True)
# [LibSVM]SVC(C=1.2, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.2, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.2, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, verbose=True)
# [LibSVM]SVC(C=1.25, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.25, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, degree=1, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, degree=2, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, degree=4, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, degree=5, kernel='poly', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, gamma='auto', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, kernel='sigmoid', verbose=True)
# [LibSVM]SVC(C=1.25, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# [LibSVM]

# %% [markdown]
# ## Printing model with their accuracy
#
# we can observe that when the kernel is sigmoid and gamma is not in auto mode, there is a sharp drop in the accuracy (0.35 to 0.2418). Regularization parameter does not affect the same.
#
# This indicates that Variance of X affects the model negatively when run using sigmoid kernel, Since:
#
# Gamma = Scale => 1 / (n_features * X.var())
#
# Gamma = Auto => 1 / n_features
#
# --
#
# Furthermore, if there is a value error intercepted due to incompatibility of some parameters, we will consider their accuracy to be 0

# %%
for i in svmModelArr:
    try:
        print(i)
        yPred = i.predict(xTest)
        acc = accuracy_score(yTest,yPred)
        print(acc)
    except ValueError as e:
        accList.append(0)
        continue
    
    accList.append(acc)
# Out:
# SVC(C=0.75, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=0.75, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.351
# SVC(C=0.75, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.237
# SVC(C=0.75, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.75, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.8, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=0.8, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.3512
# SVC(C=0.8, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2375
# SVC(C=0.8, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.8, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.9, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=0.9, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.3513
# SVC(C=0.9, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2363
# SVC(C=0.9, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=0.9, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.3519
# SVC(decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2363
# SVC(decision_function_shape='ovo', gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(break_ties=True, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', kernel='poly', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', gamma='auto', verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.1, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=1.1, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.3519
# SVC(C=1.1, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2366
# SVC(C=1.1, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.1, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.2, decision_function_shape='ovo', degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=1.2, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.352
# SVC(C=1.2, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2364
# SVC(C=1.2, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.2, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=1.25, decision_function_shape='ovo', degree=1, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', degree=2, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', degree=4, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', degree=5, kernel='poly',
#     verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', verbose=True)
# 0.35
# SVC(C=1.25, decision_function_shape='ovo', gamma='auto', verbose=True)
# 0.3518
# SVC(C=1.25, decision_function_shape='ovo', kernel='sigmoid', verbose=True)
# 0.2365
# SVC(C=1.25, decision_function_shape='ovo', gamma='auto', kernel='sigmoid',
#     verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=1,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=2,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='poly',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=4,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', degree=5,
#     kernel='poly', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', kernel='sigmoid',
#     verbose=True)
# SVC(C=1.25, break_ties=True, decision_function_shape='ovo', gamma='auto',
#     kernel='sigmoid', verbose=True)
# SVC(C=0.75, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, verbose=True)
# 0.35
# SVC(C=0.75, gamma='auto', verbose=True)
# 0.351
# SVC(C=0.75, kernel='sigmoid', verbose=True)
# 0.237
# SVC(C=0.75, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, verbose=True)
# 0.35
# SVC(C=0.75, break_ties=True, gamma='auto', verbose=True)
# 0.3509
# SVC(C=0.75, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2418
# SVC(C=0.75, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=0.8, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, verbose=True)
# 0.35
# SVC(C=0.8, gamma='auto', verbose=True)
# 0.3512
# SVC(C=0.8, kernel='sigmoid', verbose=True)
# 0.2375
# SVC(C=0.8, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, verbose=True)
# 0.35
# SVC(C=0.8, break_ties=True, gamma='auto', verbose=True)
# 0.3511
# SVC(C=0.8, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2423
# SVC(C=0.8, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=0.9, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, verbose=True)
# 0.35
# SVC(C=0.9, gamma='auto', verbose=True)
# 0.3513
# SVC(C=0.9, kernel='sigmoid', verbose=True)
# 0.2363
# SVC(C=0.9, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, verbose=True)
# 0.35
# SVC(C=0.9, break_ties=True, gamma='auto', verbose=True)
# 0.3512
# SVC(C=0.9, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2411
# SVC(C=0.9, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(kernel='poly', verbose=True)
# 0.35
# SVC(degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(verbose=True)
# 0.35
# SVC(gamma='auto', verbose=True)
# 0.3519
# SVC(kernel='sigmoid', verbose=True)
# 0.2363
# SVC(gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(break_ties=True, verbose=True)
# 0.35
# SVC(break_ties=True, gamma='auto', verbose=True)
# 0.3519
# SVC(break_ties=True, kernel='sigmoid', verbose=True)
# 0.2408
# SVC(break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.1, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, verbose=True)
# 0.35
# SVC(C=1.1, gamma='auto', verbose=True)
# 0.3519
# SVC(C=1.1, kernel='sigmoid', verbose=True)
# 0.2366
# SVC(C=1.1, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, verbose=True)
# 0.35
# SVC(C=1.1, break_ties=True, gamma='auto', verbose=True)
# 0.3519
# SVC(C=1.1, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2407
# SVC(C=1.1, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.2, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, verbose=True)
# 0.35
# SVC(C=1.2, gamma='auto', verbose=True)
# 0.352
# SVC(C=1.2, kernel='sigmoid', verbose=True)
# 0.2364
# SVC(C=1.2, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, verbose=True)
# 0.35
# SVC(C=1.2, break_ties=True, gamma='auto', verbose=True)
# 0.3519
# SVC(C=1.2, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2403
# SVC(C=1.2, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.25, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, verbose=True)
# 0.35
# SVC(C=1.25, gamma='auto', verbose=True)
# 0.3518
# SVC(C=1.25, kernel='sigmoid', verbose=True)
# 0.2365
# SVC(C=1.25, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, degree=1, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, degree=2, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, degree=4, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, degree=5, kernel='poly', verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, verbose=True)
# 0.35
# SVC(C=1.25, break_ties=True, gamma='auto', verbose=True)
# 0.3519
# SVC(C=1.25, break_ties=True, kernel='sigmoid', verbose=True)
# 0.2404
# SVC(C=1.25, break_ties=True, gamma='auto', kernel='sigmoid', verbose=True)
# 0.35

# %%
plt.plot(accList)
